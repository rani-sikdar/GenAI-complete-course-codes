# %%
pip install langchain_huggingface huggingface_hub

# %%
from langchain_huggingface import HuggingFaceEndpoint
from langchain.chains import LLMChain
from langchain_core.prompts import PromptTemplate

# %%
import os
HF_TOKEN = "***********"
os.environ["HF_TOKEN"] = HF_TOKEN

# %% [markdown]
# ### use any "text-generation" models from `huggingface`

# %%
repo_id="google/gemma-2-9b"
llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    task="text-generation",
    huggingfacehub_api_token= HF_TOKEN,
    )
llm
# Out:
# HuggingFaceEndpoint(repo_id='google/gemma-2-9b', huggingfacehub_api_token='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', stop_sequences=[], server_kwargs={}, model_kwargs={}, model='google/gemma-2-9b', client=<InferenceClient(model='google/gemma-2-9b', timeout=120)>, async_client=<InferenceClient(model='google/gemma-2-9b', timeout=120)>, task='text-generation')

# %%
llm.invoke("what is nlp")
# Out:
# '\n\nNeuro-linguistic programming (NLP) is a controversial form of psychotherapy that asserts that “the mind and body are inseparable” and that language is “the most powerful tool we possess.” The theory is that words and language are “more than just a vehicle for thought and communication.” This means that words have a certain effect on us and that we can influence our own thinking by changing our language.\n\nNLP is not a stand-alone psychotherapy. It is instead a collection of different techniques, such as hypnosis, cognitive-behavioral therapy, and others. It is not a substitute for traditional talk therapy. It is instead a tool that can be used to treat a wide range of mental health issues.\n\nwhat is the purpose of nlp\n\nNLP’s main purpose is to help people change their lives. NLP was developed to help people improve their lives and their relationships with others.\n\nNLP was created to help people find a way to improve their lives. It was created to help people change their l
# ...

# %%
pip install sentence-transformers

# %%
pip install langchain_community

# %% [markdown]
# ### HuggingFace Embeddings -
# we can use any embedding models

# %%
# from langchain_community.embeddings import HuggingFaceBgeEmbeddings
from langchain_huggingface import HuggingFaceEmbeddings

model_name = "BAAI/bge-small-en"
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": True}
hf = HuggingFaceEmbeddings(
    model_name=model_name, model_kwargs=model_kwargs, encode_kwargs=encode_kwargs
)

# %%
embedding = hf.embed_query("hi this is harrison")

# %%
embedding
# Out:
# [-0.043661803007125854,
#  -0.019216876477003098,
#  0.037801723927259445,
#  -0.0554828979074955,
#  0.004219571594148874,
#  0.009599270299077034,
#  0.05980199947953224,
#  0.020596832036972046,
#  0.011896011419594288,
#  0.008097521029412746,
#  0.00313086761161685,
#  -0.0745842382311821,
#  0.02128712832927704,
#  0.028768284246325493,
#  0.01636919379234314,
#  -0.0382273904979229,
#  0.04639599844813347,
#  0.0024223036598414183,
#  -0.03738134726881981,
#  -0.0065802643075585365,
#  0.046632036566734314,
#  0.006663449574261904,
#  -0.042090971022844315,
#  -0.06357259303331375,
#  0.02499615028500557,
#  0.011425279080867767,
#  -0.006768413819372654,
#  -0.013263965025544167,
#  -0.02391033060848713,
#  -0.11573261022567749,
#  -0.02224602922797203,
#  -0.011078906245529652,
#  0.022443484514951706,
#  0.0067429798655211926,
#  0.015741992741823196,
#  -0.021520083770155907,
#  -0.010607653297483921,
#  0.04447276145219803,
#  -0.03134218975901604,
# ...

# %%
res= hf.embed_query("This is a implementaion of HuggingFace-Langchain integration.")

# %%
res
# Out:
# [-0.0840635821223259,
#  -0.0017172748921439052,
#  -0.015577365644276142,
#  -0.038898393511772156,
#  -0.004249216988682747,
#  0.0020648983772844076,
#  0.0030311488080769777,
#  -0.011961553245782852,
#  0.0005758459446951747,
#  -0.029767295345664024,
#  0.000148177205119282,
#  -0.034989695996046066,
#  0.047738708555698395,
#  0.028549689799547195,
#  0.06868926435709,
#  -0.028079912066459656,
#  -0.010459814220666885,
#  0.019362200051546097,
#  0.012279591523110867,
#  0.0027865800075232983,
#  0.0443001314997673,
#  -0.0207535270601511,
#  -0.0022482944186776876,
#  -0.032831910997629166,
#  0.0033619478344917297,
#  0.10091947764158249,
#  0.008249727077782154,
#  -0.019859839230775833,
#  0.045054007321596146,
#  -0.19783365726470947,
#  0.005861765705049038,
#  -0.009881380945444107,
#  0.027383917942643166,
#  -0.011625346727669239,
#  -0.022744836285710335,
#  0.009612212888896465,
#  -0.05283385142683983,
#  0.036693036556243896,
#  -0.029347941279411316,
# ...
